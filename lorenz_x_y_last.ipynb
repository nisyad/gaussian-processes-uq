# %%
"""Varying all 3: b,c,h"""
# Out:
# 'Varying all 3: b,c,h'

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D
from L96 import *
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
np.random.seed(123)
sns.set_style('darkgrid')

# %%
"""Two-Level Lorenz 96"""

K = 4  # index for slow variables (total=4)
J = 4 # index for fast variables (total=16)
F = 10  # forcing
# b = 10
# c = 10
# h = 1

# %%
X0 = np.random.randn(K)
Y0 = np.random.randn(J*K)

print(X0.shape)
print(Y0.shape)
# Out:
# (4,)
# (16,)

# %%
n_iter = 500 #number of different parameter simulations
t = 51
dt = 0.005

b_ = np.random.uniform(5,15,n_iter)
c_ = np.random.uniform(5,15,n_iter)
#b_ = np.full(n_iter,10)
#c_ = np.full(n_iter,10)

h_ = np.random.uniform(0,2,n_iter)

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,6))

sns.distplot(h_, hist=False, ax=ax[0]).set_title('h')
sns.distplot(b_, hist=False, ax=ax[1]).set_title('b')
sns.distplot(c_, hist=False, ax=ax[2]).set_title('c')

plt.suptitle('True Distributions', fontsize=14)
plt.show()

# %%
# %%time

# out = []
# X_ = []
# Y_ = []

# for i in range(n_iter):
#     print('n_iter: ', i)
#     h = h_[i] 
#     c = c_[i] 
#     b = b_[i]
#     l96_ref = L96TwoLevel(K=K, J=J, X_init=X0, Y_init=Y0, h=h, c=c, b=b, save_dt=dt, noYhist=False)
#     l96_ref.iterate(t)
    
#     out.append(l96_ref.history)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
print('done')
# Out:
# done

# %%
# """Pickle Output Data"""

# outfile = open("F_10_i_500_T_51_dt_0.005_X_4.pkl", "wb" )
# pickle.dump(out, outfile)
# outfile.close()

# %%
"""Load Output Pickle File"""

infile = open("F_10_i_500_T_51_dt_0.005_X_4.pkl",'rb')
out = pickle.load(infile)
infile.close()

# %%
plt.plot((out[0].X.values[:1000]))

plt.show()

# %%
X_ = []
Y_ = []

for i in range(n_iter):
    X_.append((out[i]).X.values)
    Y_.append((out[i]).Y.values)

# %%
"""Discard Initial Transient Steps"""

X_ = np.array(X_)
print('X_ shape: ', X_.shape)
X_ = X_[:,:10000,:]
print('X_shape after discarding: ', X_.shape)

Y_ = np.array(Y_)
print('Y_ shape: ', Y_.shape)
Y_ = Y_[:,:10000,:]
print('Y_shape after discarding: ', Y_.shape)
# Out:
# X_ shape:  (500, 10201, 4)
# X_shape after discarding:  (500, 10000, 4)
# Y_ shape:  (500, 10201, 16)
# Y_shape after discarding:  (500, 10000, 16)

# %%
"""Reshaping Data"""

X = X_.reshape(X_.shape[0]*X_.shape[1], K)
print('X reshaped: ', X.shape)
X_last = X_[:,-1,:]
print('X_last: ', X_last.shape)


Y = Y_.reshape(Y_.shape[0]*Y_.shape[1], K*J)
print('Y reshaped: ', Y.shape)
Y_last = Y_[:,-1,:]
print('Y_last: ', Y_last.shape)


h_truth_ = []
b_truth_ = []
c_truth_ = []

for i in range(n_iter):
    temp = np.ones(X_.shape[1])*h_[i]
    temp2 = np.ones(X_.shape[1])*b_[i]
    temp3 = np.ones(X_.shape[1])*c_[i]
    h_truth_.append(temp)
    b_truth_.append(temp2)
    c_truth_.append(temp3)
    
    
h_truth_ = np.array(h_truth_)
print('h shape: ', h_truth_.shape)
h_truth = h_truth_.reshape(n_iter*X_.shape[1],1)
print('h_truth (reshaped): ', h_truth.shape)
h_truth_last = h_.reshape(-1,1)
print('h_truth_last: ', h_truth_last.shape)

b_truth_ = np.array(b_truth_)
print('b shape: ', b_truth_.shape)
b_truth = b_truth_.reshape(n_iter*X_.shape[1],1)
print('b_truth (reshaped): ', h_truth.shape)
b_truth_last = b_.reshape(-1,1)
print('b_truth_last: ', b_truth_last.shape)

c_truth_ = np.array(c_truth_)
print('c shape: ', c_truth_.shape)
c_truth = c_truth_.reshape(n_iter*X_.shape[1],1)
print('c_truth (reshaped): ', c_truth.shape)
c_truth_last = h_.reshape(-1,1)
print('c_truth_last: ', c_truth_last.shape)
# Out:
# X reshaped:  (5000000, 4)
# X_last:  (500, 4)
# Y reshaped:  (5000000, 16)
# Y_last:  (500, 16)
# h shape:  (500, 10000)
# h_truth (reshaped):  (5000000, 1)
# h_truth_last:  (500, 1)
# b shape:  (500, 10000)
# b_truth (reshaped):  (5000000, 1)
# b_truth_last:  (500, 1)
# c shape:  (500, 10000)
# c_truth (reshaped):  (5000000, 1)
# c_truth_last:  (500, 1)

# %%
# plt.figure(figsize=(6,8), frameon=True)
# plt.imshow(X[:1000, :],cmap='RdBu', aspect='auto', alpha=0.6)
# plt.xticks([0,1,2,3])
# plt.grid()
# plt.colorbar()
# #plt.show()

# plt.savefig("colormap.pdf", bbox_inches="tight")

# %%
n_points = 500

# %%
X_in = np.hstack((X_last[:n_points], Y_last[:n_points]))
dataset = np.hstack((X_in,h_truth_last[:n_points], b_truth_last[:n_points], c_truth_last[:n_points]))
np.random.shuffle(dataset)
print(dataset.shape)
# Out:
# (500, 23)

# %%
# X_in = np.hstack((X,Y))
# dataset = np.hstack((X_in,h_truth))
# np.random.shuffle(dataset)
# print(dataset.shape)

# %%
n_data = dataset.shape[0]
split = int(0.6*n_data)

X_train = dataset[:split, :K]
y_train = dataset[:split, K]
X_test = dataset[split:, :K]
y_test = dataset[split:, K]

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (300, 4)
# (200, 4)
# (300,)
# (200,)

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import StandardScaler

# Define the scaler 
scaler = StandardScaler().fit(X_train)
# Scale the train set
X_train = scaler.transform(X_train)
# Scale the test set
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential

# Import `Dense` from `keras.layers`
from keras.layers import Dense

# Initialize the constructor
model = Sequential()

# Add an input layer 
model.add(Dense(64, activation='relu', input_shape=(K,)))

model.add(Dense(32, activation='relu', input_shape=(K,)))

# Add one hidden layer 
model.add(Dense(16, activation='relu'))

# Add an output layer 
model.add(Dense(1))

# %%
model.compile(loss='mse',
              optimizer='adam',
              metrics=['mae'])

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=50, batch_size=32, verbose=1)
# Out:
# Train on 240 samples, validate on 60 samples
# Epoch 1/50
# 240/240 [==============================] - 1s 4ms/step - loss: 0.3042 - mae: 0.4610 - val_loss: 0.2090 - val_mae: 0.3767
# Epoch 2/50
# 240/240 [==============================] - 0s 114us/step - loss: 0.2114 - mae: 0.3458 - val_loss: 0.1784 - val_mae: 0.3212
# Epoch 3/50
# 240/240 [==============================] - 0s 120us/step - loss: 0.1929 - mae: 0.3203 - val_loss: 0.1761 - val_mae: 0.3146
# Epoch 4/50
# 240/240 [==============================] - 0s 115us/step - loss: 0.1805 - mae: 0.3103 - val_loss: 0.1769 - val_mae: 0.3195
# Epoch 5/50
# 240/240 [==============================] - 0s 121us/step - loss: 0.1744 - mae: 0.3086 - val_loss: 0.1769 - val_mae: 0.3253
# Epoch 6/50
# 240/240 [==============================] - 0s 119us/step - loss: 0.1725 - mae: 0.3101 - val_loss: 0.1739 - val_mae: 0.3202
# Epoch 7/50
# 240/240 [==============================] - 0s 140us/step - loss: 0.1692 - mae: 0.3015 - val_loss: 0.1664 - val_mae: 0.3086
# Epoch 8/50
# 240/240 [==============================] - 0s 116us/step - loss: 0.1664 - mae: 0.2942 - val_loss: 0.1667 - val_mae: 0.3077
# Epoch 9/50
# 240/240 [==============================] - 0s 115us/step - loss: 0.1642 - mae: 0.2920 - val_loss: 0.1655 - val_mae: 0.3071
# Epoch 10/50
# 240/240 [==============================] - 0s 112us/step - loss: 0.1642 - mae: 0.2942 - val_loss: 0.1693 - val_mae: 0.3162
# Epoch 11/50
# 240/240 [==============================] - 0s 125us/step - loss: 0.1608 - mae: 0.2899 - val_loss: 0.1650 - val_mae: 0.3073
# Epoch 12/50
# 240/240 [==============================] - 0s 112us/step - loss: 0.1596 - mae: 0.2847 - val_loss: 0.1648 - val_mae: 0.3055
# Epoch 13/50
# 240/240 [==============================] - 0s 111us/step - loss: 0.1589 - mae: 0.2841 - val_loss: 0.1709 - val_mae: 0.3177
# Epoch 14/50
# 240/240 [==============================] - 0s 116us/step - loss: 0.1579 - mae: 0.2838 - val_loss: 0.1679 - val_mae: 0.3109
# Epoch 15/50
# 240/240 [==============================] - 0s 111us/step - loss: 0.1562 - mae: 0.2814 - val_loss: 0.1647 - val_mae: 0.3059
# Epoch 16/50
# 240/240 [==============================] - 0s 115us/step - loss: 0.1557 - mae: 0.2800 - val_loss: 0.1663 - val_mae: 0.3091
# Epoch 17/50
# 240/240 [==============================] - 0s 110us/step - loss: 0.1553 - mae: 0.2808 - val_loss: 0.1696 - val_mae: 0.3144
# Epoch 18/50
# 240/240 [==============================] - 0s 113us/step - loss: 0.1547 - mae: 0.2806 - val_loss: 0.1681 - val_mae: 0.3117
# Epoch 19/50
# 240/240 [==============================] - 0s 117us/step - loss: 0.1544 - mae: 0.2802 - val_loss: 0.1666 - val_mae: 0.3096
# Epoch 20/50
# 240/240 [==============================] - 0s 117us/step - loss: 0.1531 - mae: 0.2778 - val_loss: 0.1674 - val_mae: 0.3132
# Epoch 21/50
# 240/240 [==============================] - 0s 121us/step - loss: 0.1535 - mae: 0.2784 - val_loss: 0.1650 - val_mae: 0.3086
# Epoch 22/50
# 240/240 [==============================] - 0s 145us/step - loss: 0.1534 - mae: 0.2804 - val_loss: 0.1693 - val_mae: 0.3134
# Epoch 23/50
# 240/240 [==============================] - 0s 118us/step - loss: 0.1524 - mae: 0.2795 - val_loss: 0.1658 - val_mae: 0.3050
# Epoch 24/50
# 240/240 [==============================] - 0s 116us/step - loss: 0.1515 - mae: 0.2763 - val_loss: 0.1667 - val_mae: 0.3115
# Epoch 25/50
# 240/240 [==============================] - 0s 116us/step - loss: 0.1525 - mae: 0.2812 - val_loss: 0.1711 - val_mae: 0.3186
# Epoch 26/50
# 240/240 [==============================] - 0s 128us/step - loss: 0.1502 - mae: 0.2760 - val_loss: 0.1643 - val_mae: 0.3071
# Epoch 27/50
# 240/240 [==============================] - 0s 180us/step - loss: 0.1508 - mae: 0.2764 - val_loss: 0.1644 - val_mae: 0.3076
# Epoch 28/50
# 240/240 [==============================] - 0s 120us/step - loss: 0.1499 - mae: 0.2764 - val_loss: 0.1666 - val_mae: 0.3123
# Epoch 29/50
# 240/240 [==============================] - 0s 126us/step - loss: 0.1503 - mae: 0.2767 - val_loss: 0.1669 - val_mae: 0.3103
# Epoch 30/50
# 240/240 [==============================] - 0s 121us/step - loss: 0.1492 - mae: 0.2756 - val_loss: 0.1709 - val_mae: 0.3172
# Epoch 31/50
# 240/240 [==============================] - 0s 114us/step - loss: 0.1484 - mae: 0.2745 - val_loss: 0.1638 - val_mae: 0.3066
# Epoch 32/50
# 240/240 [==============================] - 0s 117us/step - loss: 0.1480 - mae: 0.2734 - val_loss: 0.1658 - val_mae: 0.3102
# Epoch 33/50
# 240/240 [==============================] - 0s 119us/step - loss: 0.1481 - mae: 0.2739 - val_loss: 0.1669 - val_mae: 0.3089
# Epoch 34/50
# 240/240 [==============================] - 0s 121us/step - loss: 0.1470 - mae: 0.2722 - val_loss: 0.1629 - val_mae: 0.3042
# Epoch 35/50
# 240/240 [==============================] - 0s 122us/step - loss: 0.1477 - mae: 0.2727 - val_loss: 0.1658 - val_mae: 0.3093
# Epoch 36/50
# 240/240 [==============================] - 0s 117us/step - loss: 0.1469 - mae: 0.2721 - val_loss: 0.1652 - val_mae: 0.3113
# Epoch 37/50
# 240/240 [==============================] - 0s 117us/step - loss: 0.1465 - mae: 0.2740 - val_loss: 0.1673 - val_mae: 0.3129
# Epoch 38/50
# 240/240 [==============================] - 0s 124us/step - loss: 0.1461 - mae: 0.2715 - val_loss: 0.1671 - val_mae: 0.3095
# Epoch 39/50
# 240/240 [==============================] - 0s 152us/step - loss: 0.1457 - mae: 0.2719 - val_loss: 0.1664 - val_mae: 0.3114
# Epoch 40/50
# 240/240 [==============================] - 0s 123us/step - loss: 0.1463 - mae: 0.2724 - val_loss: 0.1634 - val_mae: 0.3042
# Epoch 41/50
# 240/240 [==============================] - 0s 119us/step - loss: 0.1456 - mae: 0.2722 - val_loss: 0.1669 - val_mae: 0.3131
# Epoch 42/50
# 240/240 [==============================] - 0s 128us/step - loss: 0.1453 - mae: 0.2715 - val_loss: 0.1672 - val_mae: 0.3061
# Epoch 43/50
# 240/240 [==============================] - 0s 129us/step - loss: 0.1449 - mae: 0.2707 - val_loss: 0.1691 - val_mae: 0.3165
# Epoch 44/50
# 240/240 [==============================] - 0s 124us/step - loss: 0.1443 - mae: 0.2725 - val_loss: 0.1670 - val_mae: 0.3145
# Epoch 45/50
# 240/240 [==============================] - 0s 125us/step - loss: 0.1439 - mae: 0.2703 - val_loss: 0.1638 - val_mae: 0.3013
# Epoch 46/50
# 240/240 [==============================] - 0s 137us/step - loss: 0.1435 - mae: 0.2720 - val_loss: 0.1712 - val_mae: 0.3154
# Epoch 47/50
# 240/240 [==============================] - 0s 153us/step - loss: 0.1429 - mae: 0.2711 - val_loss: 0.1688 - val_mae: 0.3134
# Epoch 48/50
# 240/240 [==============================] - 0s 124us/step - loss: 0.1423 - mae: 0.2684 - val_loss: 0.1664 - val_mae: 0.3088
# Epoch 49/50
# 240/240 [==============================] - 0s 163us/step - loss: 0.1422 - mae: 0.2684 - val_loss: 0.1670 - val_mae: 0.3114
# Epoch 50/50
# 240/240 [==============================] - 0s 138us/step - loss: 0.1418 - mae: 0.2683 - val_loss: 0.1658 - val_mae: 0.3045

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# 200/200 [==============================] - 0s 44us/step
# [0.17848096251487733, 0.3025546967983246]

# %%
pred = model.predict(X_test)

# %%
print(pred.shape)
print(y_test.shape)
# Out:
# (200, 1)
# (200,)

# %%
"""Calcualte R2 Score"""
import sklearn

sklearn.metrics.r2_score(y_test, pred, sample_weight=None, multioutput='uniform_average')
# Out:
# 0.03392312319379698

# %%
plt.figure(figsize=(8,6))

sns.distplot(pred, hist=False, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3}, label='pred')

sns.distplot(y_test, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, 'linestyle': '--'}, label='truth')


plt.title('Parameter: h (Lorenz 96)', fontsize=14)
plt.legend(fontsize=12)
plt.show()

# %%
pred.shape

# %%
h = pred[0]
b = b_truth_last[0]
c = c_truth_last[0]

l96_ref = L96TwoLevel(K=K, J=J, X_init=X0, Y_init=Y0, h=h, c=c, b=b, save_dt=dt, noYhist=False)
l96_ref.iterate(t)
    
out = l96_ref.history
x = out.X.values
x.shape

# %%
h = y_test[0]
b = b_truth_last[0]
c = c_truth_last[0]

l96_ref = L96TwoLevel(K=K, J=J, X_init=X0, Y_init=Y0, h=h, c=c, b=b, save_dt=dt, noYhist=False)
l96_ref.iterate(t)
    
out = l96_ref.history

x_ = out.X.values
x_.shape

# %%
fig = plt.figure(figsize=(10,10))

from_to = range(1000)

ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot(x[from_to,0],x[from_to,1], x[from_to,2], '.g',markersize=3, label='Prediction')
ax.plot(x_[from_to,0],x_[from_to,1], x_[from_to,2], '.b', markersize=3, label='Truth')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
ax.legend(fontsize=14)


# ax = fig.add_subplot(1, 2, 2, projection='3d')
# ax.plot(x_[:,0],x_[:,1], x_[:,2], '.b')
# ax.set_xlabel('$x_1$')
# ax.set_ylabel('$x_2$')
# ax.set_zlabel('$x_3$')
# plt.title('Truth')

plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(x[from_to,0]-x_[from_to,0], label='X1')
plt.plot(x[from_to,1]-x_[from_to,1], label='X2')
plt.plot(x[from_to,2]-x_[from_to,2], label='X3')
plt.plot(x[from_to,3]-x_[from_to,3], label='X4')
plt.ylabel('error', fontsize=12)
plt.xlabel('time steps', fontsize=12)
plt.title('X variable (from predicted h) error growth')
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Gaussian Processes

# %%
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline
from sklearn.gaussian_process import GaussianProcessRegressor 
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel, RationalQuadratic
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel
from mpl_toolkits.mplot3d import Axes3D

# %%
# n = 50  
# index = np.random.choice(X_train.shape[0], n, replace=False) 
# X_random = X_train[index]
# y_random = y_train[index]

# test_index = np.random.choice(X_test.shape[0], n, replace=False) 
# X_random_test = X_test[test_index]
# y_random_test = y_test[test_index]

# print(X_random.shape)
# print(X_random_test.shape)

# print(y_random.shape)
# print(y_random_test.shape)


# X_train = X_random
# y_train = y_random
# X_test = X_random_test
# y_test = y_random_test

# %%
print(y_train.shape)
print(X_train.shape)

# %%
# Instantiate a Gaussian Process model

#kernel = DotProduct() + WhiteKernel()
kernel = 1**2*RationalQuadratic(alpha=1, length_scale=1) + 1**2*Matern(1)
gp = GaussianProcessRegressor(kernel=kernel,n_restarts_optimizer=9)
gp.fit(X_train, y_train)
y_pred, sigma = gp.predict(X_test, return_std=True)
#gp.score(X_test+Xtrain, y_test)

# %%
gp.kernel_

# %%
xx = np.arange(0,50,1)

print(xx.shape)
print(y_pred.shape)
print(sigma.shape)

upper = y_pred+sigma
lower = y_pred-sigma

#upper = upper.reshape(500,)
#lower = lower.reshape(500,)

print(upper.shape)
print(lower.shape)

# %%
plt.figure(figsize=(16,8))

plt.plot(y_pred[:40], '-sg', linewidth=2, label='prediction')
plt.plot(y_test[:40], '-ob', label='ground truth')

plt.fill_between(xx[:40], upper[:40],lower[:40], alpha=0.5, color='pink')

plt.legend(fontsize=12)
#plt.savefig("trial.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.distplot(y_pred, hist=False, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3}, label='pred')

sns.distplot(y_test, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 3, 'linestyle': '--'}, label='truth')

plt.title('Parameter: h (Lorenz 96)', fontsize=14)
plt.legend(fontsize=12)
#plt.savefig('h_t_50_i_40_layers_24_12_6.pdf')
plt.show()

# %%
print(sklearn.metrics.mean_squared_error(y_test, y_pred, sample_weight=None, multioutput='uniform_average'))
print(sklearn.metrics.mean_absolute_error(y_test, y_pred, sample_weight=None, multioutput='uniform_average'))
print(sklearn.metrics.r2_score(y_test, y_pred, sample_weight=None, multioutput='uniform_average'))

# %%
h = y_pred[0]
b = b_truth_last[0]
c = c_truth_last[0]

l96_ref = L96TwoLevel(K=K, J=J, X_init=X0, Y_init=Y0, h=h, c=c, b=b, save_dt=dt, noYhist=False)
l96_ref.iterate(t)
    
out = l96_ref.history
x = out.X.values
x.shape

# %%
h = y_test[0]
b = b_truth_last[0]
c = c_truth_last[0]

l96_ref = L96TwoLevel(K=K, J=J, X_init=X0, Y_init=Y0, h=h, c=c, b=b, save_dt=dt, noYhist=False)
l96_ref.iterate(t)
    
out = l96_ref.history

x_ = out.X.values
x_.shape

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot(x[from_to,0],x[from_to,1], x[from_to,2], '.g', label='Prediction')
ax.plot(x_[from_to,0],x_[from_to,1], x_[from_to,2], '.b', label='Truth')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
ax.legend(fontsize=14)
#plt.title('Pred')

# ax = fig.add_subplot(1, 2, 2, projection='3d')
# ax.plot(x_[:,0],x_[:,1], x_[:,2], '.b')
# ax.set_xlabel('$x_1$')
# ax.set_ylabel('$x_2$')
# ax.set_zlabel('$x_3$')
# plt.title('Truth')

plt.show()

# %%
mtu = np.arange(0,1000)*dt

plt.figure(figsize=(12,6))
plt.plot(mtu, x[from_to,0]-x_[from_to,0], label='X1')
plt.plot(mtu, x[from_to,1]-x_[from_to,1], label='X2')
plt.plot(mtu, x[from_to,2]-x_[from_to,2], label='X3')
plt.plot(mtu, x[from_to,3]-x_[from_to,3], label='X4')
plt.ylabel('error', fontsize=12)
plt.xlabel('MTU', fontsize=12)
plt.title('X variable (from predicted h) error growth')
plt.legend(fontsize=12)
plt.show()
